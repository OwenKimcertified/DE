# %%
from pymongo import MongoClient, errors

# MongoDB Atlas
str_pass = "url"
client = MongoClient(str_pass)
db = client['http_request_meta_data']
meta_collection = db['page_meta_data']

# %%
from functools import lru_cache, wraps
import time, logging

logger = logging.getLogger(__name__)
logging.basicConfig(level = logging.ERROR)

def retry(max_attempts = 3, delay = 1):
    """실패 시 retry 하는 decorator 입니다."""
    def decorator(func : any):
        @wraps(func)
        def wrapper(*args, **kwargs):
            attempts = 0
            while attempts < max_attempts:
                try:
                    return func(*args, **kwargs)
                except errors.PyMongoError as e:
                    logger.error(f"Error: {e}, Retrying... ({attempts+1}/{max_attempts})")
                    attempts += 1
                    time.sleep(delay)    
            raise Exception(f"Failed after {max_attempts} attempts")
        return wrapper
    return decorator

def timing(func):
    """타이머 데코레이터 입니다."""
    @wraps(func)
    def wrapper(*args, **kwargs):
        start_time = time.time()
        result = func(*args, **kwargs)
        end_time = time.time()
        print(f"{func.__name__} took {end_time - start_time:.4f} seconds")
        return result
    return wrapper

def validate_inputs(validation_func):
    """입력 값에 대한 유효성 검사를 하는 데코레이터입니다."""
    def decorator(func):
        @wraps(func)
        def wrapper(*args, **kwargs):
            if not validation_func(*args, **kwargs):
                raise ValueError("Invalid input values")
            return func(*args, **kwargs)
        return wrapper
    return decorator

# %%
@retry(max_attempts = 3, delay = 2)
@lru_cache(maxsize = 128)
def extract_mongodb_meta(collection):
    li = []
    for i in collection.find():
        li.append(i)
    return li

ab = extract_mongodb_meta(meta_collection)

ab
# Out:
# [{'_id': ObjectId('6656b0b184b94d6462d0cd0f'),
#   'request': {'method': 'GET',
#    'url': 'https://www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=3&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=3&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#     'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
#     'referer': 'https://www.google.com',
#     'upgrade-insecure-requests': '1',
#     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
#     'sec-ch-ua': '"Chromium";v="124", "HeadlessChrome";v="124", "Not-A.Brand";v="99"',
#     'sec-ch-ua-mobile': '?0',
#     'sec-ch-ua-platform': '"Windows"'}},
#   'response': {'status': 200,
#    'url': 'https://www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=3&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=3&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'cache-control': 'no-store, no-cache, must-revalidate',
#     'content-encoding': 'gzip',
#     'content-language': 'ko-KR',
#     'content-security-policy': 'upgrade-insecure-requests;',
#     'content-type': 'text/html;charset=UTF-8',
#     'date': 'Wed, 29 May 2024 04:36:00 GMT',
#     'expires': 'Thu, 01 Jan 1970 00:00:00 GMT',
#     'pragma': 'no-cache',
#     'server': 'nginx',
#     'strict-transport-security': 'max-age=31536000',
#     'vary': 'Accept-Encoding',
#     'x-akamai-transformed': '9 78416 0 pmb=mTOE,3',
#     'x-hostname': 'coupang-web-prod-fu-5b8d7955b-bdvnc',
#     'x-ua-compatible': 'IE=edge'}},
#   'timestamp_page': 'Wed, 29 May 2024 04:36:00 GMT',
#   'timestamp_store': datetime.datetime(2024, 5, 29, 4, 36, 1, 709000),
#   'tag': '냉장고',
#   'tag2': 3},
#  {'_id': ObjectId('6656b0b284b94d6462d0cd10'),
#   'request': {'method': 'GET',
#    'url': 'https://www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=1&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=1&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#     'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
#     'referer': 'https://www.google.com',
#     'upgrade-insecure-requests': '1',
#     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
#     'sec-ch-ua': '"Chromium";v="124", "HeadlessChrome";v="124", "Not-A.Brand";v="99"',
#     'sec-ch-ua-mobile': '?0',
#     'sec-ch-ua-platform': '"Windows"'}},
#   'response': {'status': 200,
#    'url': 'https://www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=1&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=1&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'cache-control': 'no-store, no-cache, must-revalidate',
#     'content-encoding': 'gzip',
#     'content-language': 'ko-KR',
#     'content-security-policy': 'upgrade-insecure-requests;',
#     'content-type': 'text/html;charset=UTF-8',
#     'date': 'Wed, 29 May 2024 04:36:00 GMT',
#     'expires': 'Thu, 01 Jan 1970 00:00:00 GMT',
#     'pragma': 'no-cache',
#     'server': 'nginx',
#     'strict-transport-security': 'max-age=31536000',
#     'vary': 'Accept-Encoding',
#     'x-akamai-transformed': '9 - 0 pmb=mTOE,3',
#     'x-hostname': 'coupang-web-prod-ft-796b677db4-m7n8c',
#     'x-ua-compatible': 'IE=edge'}},
#   'timestamp_page': 'Wed, 29 May 2024 04:36:00 GMT',
#   'timestamp_store': datetime.datetime(2024, 5, 29, 4, 36, 2, 130000),
#   'tag': '냉장고',
#   'tag2': 1},
#  {'_id': ObjectId('6656b0b284b94d6462d0cd11'),
#   'request': {'method': 'GET',
#    'url': 'https://www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=5&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=5&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#     'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
#     'referer': 'https://www.google.com',
#     'upgrade-insecure-requests': '1',
#     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
#     'sec-ch-ua': '"Chromium";v="124", "HeadlessChrome";v="124", "Not-A.Brand";v="99"',
#     'sec-ch-ua-mobile': '?0',
#     'sec-ch-ua-platform': '"Windows"'}},
#   'response': {'status': 200,
#    'url': 'https://www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=5&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=5&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'cache-control': 'no-store, no-cache, must-revalidate',
#     'content-encoding': 'gzip',
#     'content-language': 'ko-KR',
#     'content-security-policy': 'upgrade-insecure-requests;',
#     'content-type': 'text/html;charset=UTF-8',
#     'date': 'Wed, 29 May 2024 04:36:00 GMT',
#     'expires': 'Thu, 01 Jan 1970 00:00:00 GMT',
#     'pragma': 'no-cache',
#     'server': 'nginx',
#     'strict-transport-security': 'max-age=31536000',
#     'vary': 'Accept-Encoding',
#     'x-akamai-transformed': '9 77931 0 pmb=mTOE,3',
#     'x-hostname': 'coupang-web-prod-ft-796b677db4-8vffk',
#     'x-ua-compatible': 'IE=edge'}},
#   'timestamp_page': 'Wed, 29 May 2024 04:36:00 GMT',
#   'timestamp_store': datetime.datetime(2024, 5, 29, 4, 36, 2, 549000),
#   'tag': '냉장고',
#   'tag2': 5},
#  {'_id': ObjectId('6656b0b284b94d6462d0cd12'),
#   'request': {'method': 'GET',
#    'url': 'https://www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=2&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=2&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#     'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
#     'referer': 'https://www.google.com',
#     'upgrade-insecure-requests': '1',
#     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
#     'sec-ch-ua': '"Chromium";v="124", "HeadlessChrome";v="124", "Not-A.Brand";v="99"',
#     'sec-ch-ua-mobile': '?0',
#     'sec-ch-ua-platform': '"Windows"'}},
#   'response': {'status': 200,
#    'url': 'https://www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=2&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=2&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'cache-control': 'no-store, no-cache, must-revalidate',
#     'content-encoding': 'gzip',
#     'content-language': 'ko-KR',
#     'content-security-policy': 'upgrade-insecure-requests;',
#     'content-type': 'text/html;charset=UTF-8',
#     'date': 'Wed, 29 May 2024 04:36:00 GMT',
#     'expires': 'Thu, 01 Jan 1970 00:00:00 GMT',
#     'pragma': 'no-cache',
#     'server': 'nginx',
#     'strict-transport-security': 'max-age=31536000',
#     'vary': 'Accept-Encoding',
#     'x-akamai-transformed': '9 - 0 pmb=mTOE,3',
#     'x-hostname': 'coupang-web-prod-ft-796b677db4-pvlp9',
#     'x-ua-compatible': 'IE=edge'}},
#   'timestamp_page': 'Wed, 29 May 2024 04:36:00 GMT',
#   'timestamp_store': datetime.datetime(2024, 5, 29, 4, 36, 2, 567000),
#   'tag': '냉장고',
#   'tag2': 2},
#  {'_id': ObjectId('6656b0b284b94d6462d0cd13'),
#   'request': {'method': 'GET',
#    'url': 'https://www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=4&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=4&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#     'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
#     'referer': 'https://www.google.com',
#     'upgrade-insecure-requests': '1',
#     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
#     'sec-ch-ua': '"Chromium";v="124", "HeadlessChrome";v="124", "Not-A.Brand";v="99"',
#     'sec-ch-ua-mobile': '?0',
#     'sec-ch-ua-platform': '"Windows"'}},
#   'response': {'status': 200,
#    'url': 'https://www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=4&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=4&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'cache-control': 'no-store, no-cache, must-revalidate',
#     'content-encoding': 'gzip',
#     'content-language': 'ko-KR',
#     'content-security-policy': 'upgrade-insecure-requests;',
#     'content-type': 'text/html;charset=UTF-8',
#     'date': 'Wed, 29 May 2024 04:36:00 GMT',
#     'expires': 'Thu, 01 Jan 1970 00:00:00 GMT',
#     'pragma': 'no-cache',
#     'server': 'nginx',
#     'strict-transport-security': 'max-age=31536000',
#     'vary': 'Accept-Encoding',
#     'x-akamai-transformed': '9 - 0 pmb=mTOE,3',
#     'x-hostname': 'coupang-web-prod-ft-796b677db4-hgckt',
#     'x-ua-compatible': 'IE=edge'}},
#   'timestamp_page': 'Wed, 29 May 2024 04:36:00 GMT',
#   'timestamp_store': datetime.datetime(2024, 5, 29, 4, 36, 2, 695000),
#   'tag': '노트북',
#   'tag2': 4},
#  {'_id': ObjectId('6656b0b284b94d6462d0cd14'),
#   'request': {'method': 'GET',
#    'url': 'https://www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=2&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=2&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#     'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
#     'referer': 'https://www.google.com',
#     'upgrade-insecure-requests': '1',
#     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
#     'sec-ch-ua': '"Chromium";v="124", "HeadlessChrome";v="124", "Not-A.Brand";v="99"',
#     'sec-ch-ua-mobile': '?0',
#     'sec-ch-ua-platform': '"Windows"'}},
#   'response': {'status': 200,
#    'url': 'https://www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=2&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=2&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'cache-control': 'no-store, no-cache, must-revalidate',
#     'content-encoding': 'gzip',
#     'content-language': 'ko-KR',
#     'content-security-policy': 'upgrade-insecure-requests;',
#     'content-type': 'text/html;charset=UTF-8',
#     'date': 'Wed, 29 May 2024 04:36:00 GMT',
#     'expires': 'Thu, 01 Jan 1970 00:00:00 GMT',
#     'pragma': 'no-cache',
#     'server': 'nginx',
#     'strict-transport-security': 'max-age=31536000',
#     'vary': 'Accept-Encoding',
#     'x-akamai-transformed': '9 - 0 pmb=mTOE,3',
#     'x-hostname': 'coupang-web-prod-ft-796b677db4-xmhd4',
#     'x-ua-compatible': 'IE=edge'}},
#   'timestamp_page': 'Wed, 29 May 2024 04:36:00 GMT',
#   'timestamp_store': datetime.datetime(2024, 5, 29, 4, 36, 2, 817000),
#   'tag': '노트북',
#   'tag2': 2},
#  {'_id': ObjectId('6656b0b284b94d6462d0cd15'),
#   'request': {'method': 'GET',
#    'url': 'https://www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=4&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=4&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#     'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
#     'referer': 'https://www.google.com',
#     'upgrade-insecure-requests': '1',
#     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
#     'sec-ch-ua': '"Chromium";v="124", "HeadlessChrome";v="124", "Not-A.Brand";v="99"',
#     'sec-ch-ua-mobile': '?0',
#     'sec-ch-ua-platform': '"Windows"'}},
#   'response': {'status': 200,
#    'url': 'https://www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=4&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=4&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'cache-control': 'no-store, no-cache, must-revalidate',
#     'content-encoding': 'gzip',
#     'content-language': 'ko-KR',
#     'content-security-policy': 'upgrade-insecure-requests;',
#     'content-type': 'text/html;charset=UTF-8',
#     'date': 'Wed, 29 May 2024 04:36:00 GMT',
#     'expires': 'Thu, 01 Jan 1970 00:00:00 GMT',
#     'pragma': 'no-cache',
#     'server': 'nginx',
#     'strict-transport-security': 'max-age=31536000',
#     'vary': 'Accept-Encoding',
#     'x-akamai-transformed': '9 77573 0 pmb=mTOE,3',
#     'x-hostname': 'coupang-web-prod-ft-796b677db4-gwqg9',
#     'x-ua-compatible': 'IE=edge'}},
#   'timestamp_page': 'Wed, 29 May 2024 04:36:00 GMT',
#   'timestamp_store': datetime.datetime(2024, 5, 29, 4, 36, 2, 953000),
#   'tag': '냉장고',
#   'tag2': 4},
#  {'_id': ObjectId('6656b0b384b94d6462d0cd16'),
#   'request': {'method': 'GET',
#    'url': 'https://www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=5&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=5&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#     'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
#     'referer': 'https://www.google.com',
#     'upgrade-insecure-requests': '1',
#     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
#     'sec-ch-ua': '"Chromium";v="124", "HeadlessChrome";v="124", "Not-A.Brand";v="99"',
#     'sec-ch-ua-mobile': '?0',
#     'sec-ch-ua-platform': '"Windows"'}},
#   'response': {'status': 200,
#    'url': 'https://www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=5&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=5&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'cache-control': 'no-store, no-cache, must-revalidate',
#     'content-encoding': 'gzip',
#     'content-language': 'ko-KR',
#     'content-security-policy': 'upgrade-insecure-requests;',
#     'content-type': 'text/html;charset=UTF-8',
#     'date': 'Wed, 29 May 2024 04:36:00 GMT',
#     'expires': 'Thu, 01 Jan 1970 00:00:00 GMT',
#     'pragma': 'no-cache',
#     'server': 'nginx',
#     'strict-transport-security': 'max-age=31536000',
#     'vary': 'Accept-Encoding',
#     'x-akamai-transformed': '9 - 0 pmb=mTOE,3',
#     'x-hostname': 'coupang-web-prod-ft-796b677db4-7h9ww',
#     'x-ua-compatible': 'IE=edge'}},
#   'timestamp_page': 'Wed, 29 May 2024 04:36:00 GMT',
#   'timestamp_store': datetime.datetime(2024, 5, 29, 4, 36, 3, 29000),
#   'tag': '노트북',
#   'tag2': 5},
#  {'_id': ObjectId('6656b0b384b94d6462d0cd17'),
#   'request': {'method': 'GET',
#    'url': 'https://www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=1&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=1&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#     'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
#     'referer': 'https://www.google.com',
#     'upgrade-insecure-requests': '1',
#     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
#     'sec-ch-ua': '"Chromium";v="124", "HeadlessChrome";v="124", "Not-A.Brand";v="99"',
#     'sec-ch-ua-mobile': '?0',
#     'sec-ch-ua-platform': '"Windows"'}},
#   'response': {'status': 200,
#    'url': 'https://www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=1&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=1&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'cache-control': 'no-store, no-cache, must-revalidate',
#     'content-encoding': 'gzip',
#     'content-language': 'ko-KR',
#     'content-security-policy': 'upgrade-insecure-requests;',
#     'content-type': 'text/html;charset=UTF-8',
#     'date': 'Wed, 29 May 2024 04:36:00 GMT',
#     'expires': 'Thu, 01 Jan 1970 00:00:00 GMT',
#     'pragma': 'no-cache',
#     'server': 'nginx',
#     'strict-transport-security': 'max-age=31536000',
#     'vary': 'Accept-Encoding',
#     'x-akamai-transformed': '9 - 0 pmb=mTOE,3',
#     'x-hostname': 'coupang-web-prod-fu-5b8d7955b-sj87g',
#     'x-ua-compatible': 'IE=edge'}},
#   'timestamp_page': 'Wed, 29 May 2024 04:36:00 GMT',
#   'timestamp_store': datetime.datetime(2024, 5, 29, 4, 36, 3, 387000),
#   'tag': '노트북',
#   'tag2': 1},
#  {'_id': ObjectId('6656b0b384b94d6462d0cd18'),
#   'request': {'method': 'GET',
#    'url': 'https://www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=3&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=3&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#     'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
#     'referer': 'https://www.google.com',
#     'upgrade-insecure-requests': '1',
#     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
#     'sec-ch-ua': '"Chromium";v="124", "HeadlessChrome";v="124", "Not-A.Brand";v="99"',
#     'sec-ch-ua-mobile': '?0',
#     'sec-ch-ua-platform': '"Windows"'}},
#   'response': {'status': 200,
#    'url': 'https://www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=3&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=3&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'cache-control': 'no-store, no-cache, must-revalidate',
#     'content-encoding': 'gzip',
#     'content-language': 'ko-KR',
#     'content-security-policy': 'upgrade-insecure-requests;',
#     'content-type': 'text/html;charset=UTF-8',
#     'date': 'Wed, 29 May 2024 04:36:00 GMT',
#     'expires': 'Thu, 01 Jan 1970 00:00:00 GMT',
#     'pragma': 'no-cache',
#     'server': 'nginx',
#     'strict-transport-security': 'max-age=31536000',
#     'vary': 'Accept-Encoding',
#     'x-akamai-transformed': '9 - 0 pmb=mTOE,3',
#     'x-hostname': 'coupang-web-prod-ft-796b677db4-klmqq',
#     'x-ua-compatible': 'IE=edge'}},
#   'timestamp_page': 'Wed, 29 May 2024 04:36:00 GMT',
#   'timestamp_store': datetime.datetime(2024, 5, 29, 4, 36, 3, 414000),
#   'tag': '노트북',
#   'tag2': 3},
#  {'_id': ObjectId('665e34428730ff16d8792335'),
#   'request': {'method': 'GET',
#    'url': 'https://www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=14&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=14&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#     'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
#     'referer': 'https://www.google.com',
#     'upgrade-insecure-requests': '1',
#     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
#     'sec-ch-ua': '"Chromium";v="124", "HeadlessChrome";v="124", "Not-A.Brand";v="99"',
#     'sec-ch-ua-mobile': '?0',
#     'sec-ch-ua-platform': '"Windows"'}},
#   'response': {'status': 200,
#    'url': 'https://www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=14&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=14&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'cache-control': 'no-store, no-cache, must-revalidate',
#     'content-encoding': 'gzip',
#     'content-language': 'ko-KR',
#     'content-security-policy': 'upgrade-insecure-requests;',
#     'content-type': 'text/html;charset=UTF-8',
#     'date': 'Mon, 03 Jun 2024 21:23:12 GMT',
#     'expires': 'Thu, 01 Jan 1970 00:00:00 GMT',
#     'pragma': 'no-cache',
#     'server': 'nginx',
#     'strict-transport-security': 'max-age=31536000',
#     'vary': 'Accept-Encoding',
#     'x-akamai-transformed': '9 - 0 pmb=mTOE,1',
#     'x-hostname': 'coupang-web-prod-ft-79c9447fd9-lfv25',
#     'x-ua-compatible': 'IE=edge'}},
#   'timestamp_page': 'Mon, 03 Jun 2024 21:23:12 GMT',
#   'timestamp_store': datetime.datetime(2024, 6, 3, 21, 23, 14, 29000),
#   'tag': '노트북',
#   'tag2': 14},
#  {'_id': ObjectId('665e34428730ff16d8792336'),
#   'request': {'method': 'GET',
#    'url': 'https://www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=7&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=7&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#     'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
#     'referer': 'https://www.google.com',
#     'upgrade-insecure-requests': '1',
#     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
#     'sec-ch-ua': '"Chromium";v="124", "HeadlessChrome";v="124", "Not-A.Brand";v="99"',
#     'sec-ch-ua-mobile': '?0',
#     'sec-ch-ua-platform': '"Windows"'}},
#   'response': {'status': 200,
#    'url': 'https://www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=7&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=7&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'cache-control': 'no-store, no-cache, must-revalidate',
#     'content-encoding': 'gzip',
#     'content-language': 'ko-KR',
#     'content-security-policy': 'upgrade-insecure-requests;',
#     'content-type': 'text/html;charset=UTF-8',
#     'date': 'Mon, 03 Jun 2024 21:23:12 GMT',
#     'expires': 'Thu, 01 Jan 1970 00:00:00 GMT',
#     'pragma': 'no-cache',
#     'server': 'nginx',
#     'strict-transport-security': 'max-age=31536000',
#     'vary': 'Accept-Encoding',
#     'x-akamai-transformed': '9 - 0 pmb=mTOE,1',
#     'x-hostname': 'coupang-web-prod-ft-79c9447fd9-dnft9',
#     'x-ua-compatible': 'IE=edge'}},
#   'timestamp_page': 'Mon, 03 Jun 2024 21:23:12 GMT',
#   'timestamp_store': datetime.datetime(2024, 6, 3, 21, 23, 14, 195000),
#   'tag': '냉장고',
#   'tag2': 7},
#  {'_id': ObjectId('665e37af4a8f53f125a23b3a'),
#   'request': {'method': 'GET',
#    'url': 'https://www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=11&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=11&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#     'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
#     'referer': 'https://www.google.com',
#     'upgrade-insecure-requests': '1',
#     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
#     'sec-ch-ua': '"HeadlessChrome";v="125", "Chromium";v="125", "Not.A/Brand";v="24"',
#     'sec-ch-ua-mobile': '?0',
#     'sec-ch-ua-platform': '"Windows"'}},
#   'response': {'status': 200,
#    'url': 'https://www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=11&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=11&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'cache-control': 'no-store, no-cache, must-revalidate',
#     'content-encoding': 'gzip',
#     'content-language': 'ko-KR',
#     'content-security-policy': 'upgrade-insecure-requests;',
#     'content-type': 'text/html;charset=UTF-8',
#     'date': 'Mon, 03 Jun 2024 21:37:49 GMT',
#     'expires': 'Thu, 01 Jan 1970 00:00:00 GMT',
#     'pragma': 'no-cache',
#     'server': 'nginx',
#     'strict-transport-security': 'max-age=31536000',
#     'vary': 'Accept-Encoding',
#     'x-akamai-transformed': '9 - 0 pmb=mTOE,1',
#     'x-hostname': 'coupang-web-prod-ft-79c9447fd9-lfv25',
#     'x-ua-compatible': 'IE=edge'}},
#   'timestamp_page': 'Mon, 03 Jun 2024 21:37:49 GMT',
#   'timestamp_store': datetime.datetime(2024, 6, 3, 21, 37, 51, 678000),
#   'tag': '냉장고',
#   'tag2': 11},
#  {'_id': ObjectId('665e37af4a8f53f125a23b3b'),
#   'request': {'method': 'GET',
#    'url': 'https://www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=5&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=5&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#     'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
#     'referer': 'https://www.google.com',
#     'upgrade-insecure-requests': '1',
#     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
#     'sec-ch-ua': '"HeadlessChrome";v="125", "Chromium";v="125", "Not.A/Brand";v="24"',
#     'sec-ch-ua-mobile': '?0',
#     'sec-ch-ua-platform': '"Windows"'}},
#   'response': {'status': 200,
#    'url': 'https://www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=5&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=5&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'cache-control': 'no-store, no-cache, must-revalidate',
#     'content-encoding': 'gzip',
#     'content-language': 'ko-KR',
#     'content-security-policy': 'upgrade-insecure-requests;',
#     'content-type': 'text/html;charset=UTF-8',
#     'date': 'Mon, 03 Jun 2024 21:37:49 GMT',
#     'expires': 'Thu, 01 Jan 1970 00:00:00 GMT',
#     'pragma': 'no-cache',
#     'server': 'nginx',
#     'strict-transport-security': 'max-age=31536000',
#     'vary': 'Accept-Encoding',
#     'x-akamai-transformed': '9 - 0 pmb=mTOE,1',
#     'x-hostname': 'coupang-web-prod-fu-7c6b5d7c56-m4glb',
#     'x-ua-compatible': 'IE=edge'}},
#   'timestamp_page': 'Mon, 03 Jun 2024 21:37:49 GMT',
#   'timestamp_store': datetime.datetime(2024, 6, 3, 21, 37, 51, 867000),
#   'tag': '냉장고',
#   'tag2': 5},
#  {'_id': ObjectId('665e37af4a8f53f125a23b3c'),
#   'request': {'method': 'GET',
#    'url': 'https://www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=14&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=14&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#     'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
#     'referer': 'https://www.google.com',
#     'upgrade-insecure-requests': '1',
#     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
#     'sec-ch-ua': '"HeadlessChrome";v="125", "Chromium";v="125", "Not.A/Brand";v="24"',
#     'sec-ch-ua-mobile': '?0',
#     'sec-ch-ua-platform': '"Windows"'}},
#   'response': {'status': 200,
#    'url': 'https://www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=14&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%83%89%EC%9E%A5%EA%B3%A0&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=14&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'cache-control': 'no-store, no-cache, must-revalidate',
#     'content-encoding': 'gzip',
#     'content-language': 'ko-KR',
#     'content-security-policy': 'upgrade-insecure-requests;',
#     'content-type': 'text/html;charset=UTF-8',
#     'date': 'Mon, 03 Jun 2024 21:37:48 GMT',
#     'expires': 'Thu, 01 Jan 1970 00:00:00 GMT',
#     'pragma': 'no-cache',
#     'server': 'nginx',
#     'strict-transport-security': 'max-age=31536000',
#     'vary': 'Accept-Encoding',
#     'x-akamai-transformed': '9 - 0 pmb=mTOE,1',
#     'x-hostname': 'coupang-web-prod-fu-7c6b5d7c56-hwxxt',
#     'x-ua-compatible': 'IE=edge'}},
#   'timestamp_page': 'Mon, 03 Jun 2024 21:37:48 GMT',
#   'timestamp_store': datetime.datetime(2024, 6, 3, 21, 37, 51, 985000),
#   'tag': '냉장고',
#   'tag2': 14},
#  {'_id': ObjectId('665e37b04a8f53f125a23b3d'),
#   'request': {'method': 'GET',
#    'url': 'https://www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=19&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=19&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#     'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
#     'referer': 'https://www.google.com',
#     'upgrade-insecure-requests': '1',
#     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
#     'sec-ch-ua': '"HeadlessChrome";v="125", "Chromium";v="125", "Not.A/Brand";v="24"',
#     'sec-ch-ua-mobile': '?0',
#     'sec-ch-ua-platform': '"Windows"'}},
#   'response': {'status': 200,
#    'url': 'https://www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=19&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=19&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'cache-control': 'no-store, no-cache, must-revalidate',
#     'content-encoding': 'gzip',
#     'content-language': 'ko-KR',
#     'content-security-policy': 'upgrade-insecure-requests;',
#     'content-type': 'text/html;charset=UTF-8',
#     'date': 'Mon, 03 Jun 2024 21:37:49 GMT',
#     'expires': 'Thu, 01 Jan 1970 00:00:00 GMT',
#     'pragma': 'no-cache',
#     'server': 'nginx',
#     'strict-transport-security': 'max-age=31536000',
#     'vary': 'Accept-Encoding',
#     'x-akamai-transformed': '9 - 0 pmb=mTOE,1',
#     'x-hostname': 'coupang-web-prod-ft-79c9447fd9-fbmg8',
#     'x-ua-compatible': 'IE=edge'}},
#   'timestamp_page': 'Mon, 03 Jun 2024 21:37:49 GMT',
#   'timestamp_store': datetime.datetime(2024, 6, 3, 21, 37, 52, 11000),
#   'tag': '노트북',
#   'tag2': 19},
#  {'_id': ObjectId('665e37b04a8f53f125a23b3e'),
#   'request': {'method': 'GET',
#    'url': 'https://www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=5&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=5&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#     'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
#     'referer': 'https://www.google.com',
#     'upgrade-insecure-requests': '1',
#     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
#     'sec-ch-ua': '"HeadlessChrome";v="125", "Chromium";v="125", "Not.A/Brand";v="24"',
#     'sec-ch-ua-mobile': '?0',
#     'sec-ch-ua-platform': '"Windows"'}},
#   'response': {'status': 200,
#    'url': 'https://www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=5&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'domain': 'www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=5&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
#    'header': {'cache-control': 'no-store, no-cache, must-revalidate',
#     'content-encoding': 'gzip',
#     'content-language': 'ko-KR',
#     'content-security-policy': 'upgrade-insecure-requests;',
#     'content-type': 'text/html;charset=UTF-8',
#     'date': 'Mon, 03 Jun 2024 21:37:48 GMT',
#     'expires': 'Thu, 01 Jan 1970 00:00:00 GMT',
#     'pragma': 'no-cache',
#     'server': 'nginx',
#     'strict-transport-security': 'max-age=31536000',
#     'vary': 'Accept-Encoding',
#     'x-akamai-transformed': '9 - 0 pmb=mTOE,1',
#     'x-hostname': 'coupang-web-prod-ft-79c9447fd9-cjlzq',
#     'x-ua-compatible': 'IE=edge'}},
#   'timestamp_page': 'Mon, 03 Jun 2024 21:37:48 GMT',
#   'timestamp_store': datetime.datetime(2024, 6, 3, 21, 37, 52, 109000),
#   'tag': '노트북',
#   'tag2': 5},
#  {'_id': ObjectId('665e37b04a8f53f125a23b3f'),
#   'request': {'method': 'GET',
#    'url': 'https://www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=recent&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=4&rocketAll=false&searchIndexingToken=1=9&backgroundColor=',
# ...
#     'sec-ch-ua': '"HeadlessChrome";v="125", "Chromium";v="125", "Not.A/Brand";v="24"',
#     'sec-ch-ua-mobile': '?0',
#     'sec-ch-ua-platform': '"Windows"'}},
#   'response': {'status': 200,
#    'url': 'https://www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=2',
#    'domain': 'www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=2',
#    'header': {'cache-control': 'private, no-cache, no-store, max-age=0, must-revalidate',
#     'cf-cache-status': 'DYNAMIC',
#     'cf-ray': '892af21c8c15aa62-ICN',
#     'content-encoding': 'gzip',
#     'content-type': 'text/html; charset=utf-8',
#     'date': 'Wed, 12 Jun 2024 15:41:33 GMT',
#     'server': 'cloudflare',
#     'vary': 'Accept-Encoding',
#     'x-powered-by': 'Next.js'}},
#   'timestamp_page': 'Wed, 12 Jun 2024 15:41:33 GMT',
#   'timestamp_store': datetime.datetime(2024, 6, 12, 15, 41, 37, 236000),
#   'tag': '냉동'},
#  {'_id': ObjectId('6669c22429c2e074eee78b09'),
#   'request': {'method': 'GET',
#    'url': 'https://www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=1',
#    'domain': 'www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=1',
#    'header': {'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#     'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
#     'referer': 'https://www.google.com',
#     'upgrade-insecure-requests': '1',
#     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
#     'sec-ch-ua': '"HeadlessChrome";v="125", "Chromium";v="125", "Not.A/Brand";v="24"',
#     'sec-ch-ua-mobile': '?0',
#     'sec-ch-ua-platform': '"Windows"'}},
#   'response': {'status': 200,
#    'url': 'https://www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=1',
#    'domain': 'www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=1',
#    'header': {'cache-control': 'private, no-cache, no-store, max-age=0, must-revalidate',
#     'cf-cache-status': 'DYNAMIC',
#     'cf-ray': '892af4f13e8b30d3-ICN',
#     'content-encoding': 'gzip',
#     'content-type': 'text/html; charset=utf-8',
#     'date': 'Wed, 12 Jun 2024 15:43:29 GMT',
#     'server': 'cloudflare',
#     'vary': 'Accept-Encoding',
#     'x-powered-by': 'Next.js'}},
#   'timestamp_page': 'Wed, 12 Jun 2024 15:43:29 GMT',
#   'timestamp_store': datetime.datetime(2024, 6, 12, 15, 43, 32, 986000),
#   'tag': '냉동'},
#  {'_id': ObjectId('6669c22e29c2e074eee78b0a'),
#   'request': {'method': 'GET',
#    'url': 'https://www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=2',
#    'domain': 'www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=2',
#    'header': {'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#     'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
#     'referer': 'https://www.google.com',
#     'upgrade-insecure-requests': '1',
#     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
#     'sec-ch-ua': '"HeadlessChrome";v="125", "Chromium";v="125", "Not.A/Brand";v="24"',
#     'sec-ch-ua-mobile': '?0',
#     'sec-ch-ua-platform': '"Windows"'}},
#   'response': {'status': 200,
#    'url': 'https://www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=2',
#    'domain': 'www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=2',
#    'header': {'cache-control': 'private, no-cache, no-store, max-age=0, must-revalidate',
#     'cf-cache-status': 'DYNAMIC',
#     'cf-ray': '892af52b2ec3aa4f-ICN',
#     'content-encoding': 'gzip',
#     'content-type': 'text/html; charset=utf-8',
#     'date': 'Wed, 12 Jun 2024 15:43:38 GMT',
#     'server': 'cloudflare',
#     'vary': 'Accept-Encoding',
#     'x-powered-by': 'Next.js'}},
#   'timestamp_page': 'Wed, 12 Jun 2024 15:43:38 GMT',
#   'timestamp_store': datetime.datetime(2024, 6, 12, 15, 43, 42, 255000),
#   'tag': '냉동'},
#  {'_id': ObjectId('6669d491806d99ca150379f1'),
#   'request': {'method': 'GET',
#    'url': 'https://www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=1',
#    'domain': 'www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=1',
#    'header': {'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#     'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
#     'referer': 'https://www.google.com',
#     'upgrade-insecure-requests': '1',
#     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
#     'sec-ch-ua': '"HeadlessChrome";v="125", "Chromium";v="125", "Not.A/Brand";v="24"',
#     'sec-ch-ua-mobile': '?0',
#     'sec-ch-ua-platform': '"Windows"'}},
#   'response': {'status': 200,
#    'url': 'https://www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=1',
#    'domain': 'www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=1',
#    'header': {'cache-control': 'private, no-cache, no-store, max-age=0, must-revalidate',
#     'cf-cache-status': 'DYNAMIC',
#     'cf-ray': '892b681729d9aa7d-ICN',
#     'content-encoding': 'gzip',
#     'content-type': 'text/html; charset=utf-8',
#     'date': 'Wed, 12 Jun 2024 17:02:05 GMT',
#     'server': 'cloudflare',
#     'vary': 'Accept-Encoding',
#     'x-powered-by': 'Next.js'}},
#   'timestamp_page': 'Wed, 12 Jun 2024 17:02:05 GMT',
#   'timestamp_store': datetime.datetime(2024, 6, 12, 17, 2, 9, 366000),
#   'tag': '냉동'},
#  {'_id': ObjectId('6669d49a806d99ca150379f2'),
#   'request': {'method': 'GET',
#    'url': 'https://www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=2',
#    'domain': 'www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=2',
#    'header': {'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#     'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
#     'referer': 'https://www.google.com',
#     'upgrade-insecure-requests': '1',
#     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
#     'sec-ch-ua': '"HeadlessChrome";v="125", "Chromium";v="125", "Not.A/Brand";v="24"',
#     'sec-ch-ua-mobile': '?0',
#     'sec-ch-ua-platform': '"Windows"'}},
#   'response': {'status': 200,
#    'url': 'https://www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=2',
#    'domain': 'www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=2',
#    'header': {'cache-control': 'private, no-cache, no-store, max-age=0, must-revalidate',
#     'cf-cache-status': 'DYNAMIC',
#     'cf-ray': '892b68536be2326f-ICN',
#     'content-encoding': 'gzip',
#     'content-type': 'text/html; charset=utf-8',
#     'date': 'Wed, 12 Jun 2024 17:02:15 GMT',
#     'server': 'cloudflare',
#     'vary': 'Accept-Encoding',
#     'x-powered-by': 'Next.js'}},
#   'timestamp_page': 'Wed, 12 Jun 2024 17:02:15 GMT',
#   'timestamp_store': datetime.datetime(2024, 6, 12, 17, 2, 18, 988000),
#   'tag': '냉동'},
#  {'_id': ObjectId('6674de37b1b8721ee67fabba'),
#   'request': {'method': 'GET',
#    'url': 'https://www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=1',
#    'domain': 'www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=1',
#    'header': {'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#     'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
#     'referer': 'https://www.google.com',
#     'upgrade-insecure-requests': '1',
#     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
#     'sec-ch-ua': '"HeadlessChrome";v="125", "Chromium";v="125", "Not.A/Brand";v="24"',
#     'sec-ch-ua-mobile': '?0',
#     'sec-ch-ua-platform': '"Windows"'}},
#   'response': {'status': 200,
#    'url': 'https://www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=1',
#    'domain': 'www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=1',
#    'header': {'cache-control': 'private, no-cache, no-store, max-age=0, must-revalidate',
#     'cf-cache-status': 'DYNAMIC',
#     'cf-ray': '89706469997b3085-ICN',
#     'content-encoding': 'gzip',
#     'content-type': 'text/html; charset=utf-8',
#     'date': 'Fri, 21 Jun 2024 01:58:12 GMT',
#     'server': 'cloudflare',
#     'vary': 'Accept-Encoding',
#     'x-powered-by': 'Next.js'}},
#   'timestamp_page': 'Fri, 21 Jun 2024 01:58:12 GMT',
#   'timestamp_store': datetime.datetime(2024, 6, 21, 1, 58, 15, 112000),
#   'tag': '냉동'},
#  {'_id': ObjectId('6674de7e92be10f6608eed5b'),
#   'request': {'method': 'GET',
#    'url': 'https://www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=1',
#    'domain': 'www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=1',
#    'header': {'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#     'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
#     'referer': 'https://www.google.com',
#     'upgrade-insecure-requests': '1',
#     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
#     'sec-ch-ua': '"HeadlessChrome";v="125", "Chromium";v="125", "Not.A/Brand";v="24"',
#     'sec-ch-ua-mobile': '?0',
#     'sec-ch-ua-platform': '"Windows"'}},
#   'response': {'status': 200,
#    'url': 'https://www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=1',
#    'domain': 'www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=1',
#    'header': {'cache-control': 'private, no-cache, no-store, max-age=0, must-revalidate',
#     'cf-cache-status': 'DYNAMIC',
#     'cf-ray': '89706628dbba327d-ICN',
#     'content-encoding': 'gzip',
#     'content-type': 'text/html; charset=utf-8',
#     'date': 'Fri, 21 Jun 2024 01:59:24 GMT',
#     'server': 'cloudflare',
#     'vary': 'Accept-Encoding',
#     'x-powered-by': 'Next.js'}},
#   'timestamp_page': 'Fri, 21 Jun 2024 01:59:24 GMT',
#   'timestamp_store': datetime.datetime(2024, 6, 21, 1, 59, 26, 791000),
#   'tag': '냉동'},
#  {'_id': ObjectId('6674deb46246725cd79e36a5'),
#   'request': {'method': 'GET',
#    'url': 'https://www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=1',
#    'domain': 'www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=1',
#    'header': {'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#     'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
#     'referer': 'https://www.google.com',
#     'upgrade-insecure-requests': '1',
#     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
#     'sec-ch-ua': '"HeadlessChrome";v="125", "Chromium";v="125", "Not.A/Brand";v="24"',
#     'sec-ch-ua-mobile': '?0',
#     'sec-ch-ua-platform': '"Windows"'}},
#   'response': {'status': 200,
#    'url': 'https://www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=1',
#    'domain': 'www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=1',
#    'header': {'cache-control': 'private, no-cache, no-store, max-age=0, must-revalidate',
#     'cf-cache-status': 'DYNAMIC',
#     'cf-ray': '89706770dbddaa5f-ICN',
#     'content-encoding': 'gzip',
#     'content-type': 'text/html; charset=utf-8',
#     'date': 'Fri, 21 Jun 2024 02:00:16 GMT',
#     'server': 'cloudflare',
#     'vary': 'Accept-Encoding',
#     'x-powered-by': 'Next.js'}},
#   'timestamp_page': 'Fri, 21 Jun 2024 02:00:16 GMT',
#   'timestamp_store': datetime.datetime(2024, 6, 21, 2, 0, 20, 52000),
#   'tag': '냉동'},
#  {'_id': ObjectId('6674dec66246725cd79e36a6'),
#   'request': {'method': 'GET',
#    'url': 'https://www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=2',
#    'domain': 'www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=2',
#    'header': {'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#     'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
#     'referer': 'https://www.google.com',
#     'upgrade-insecure-requests': '1',
#     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
#     'sec-ch-ua': '"HeadlessChrome";v="125", "Chromium";v="125", "Not.A/Brand";v="24"',
#     'sec-ch-ua-mobile': '?0',
#     'sec-ch-ua-platform': '"Windows"'}},
#   'response': {'status': 200,
#    'url': 'https://www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=2',
#    'domain': 'www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=2',
#    'header': {'cache-control': 'private, no-cache, no-store, max-age=0, must-revalidate',
#     'cf-cache-status': 'DYNAMIC',
#     'cf-ray': '897067e59e5faa5c-ICN',
#     'content-encoding': 'gzip',
#     'content-type': 'text/html; charset=utf-8',
#     'date': 'Fri, 21 Jun 2024 02:00:35 GMT',
#     'server': 'cloudflare',
#     'vary': 'Accept-Encoding',
#     'x-powered-by': 'Next.js'}},
#   'timestamp_page': 'Fri, 21 Jun 2024 02:00:35 GMT',
#   'timestamp_store': datetime.datetime(2024, 6, 21, 2, 0, 38, 153000),
#   'tag': '냉동'},
#  {'_id': ObjectId('6674fa18439eca10b0679165'),
#   'request': {'method': 'GET',
#    'url': 'https://www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=1',
#    'domain': 'www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=1',
#    'header': {'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#     'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
#     'referer': 'https://www.google.com',
#     'upgrade-insecure-requests': '1',
#     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
#     'sec-ch-ua': '"HeadlessChrome";v="125", "Chromium";v="125", "Not.A/Brand";v="24"',
#     'sec-ch-ua-mobile': '?0',
#     'sec-ch-ua-platform': '"Windows"'}},
#   'response': {'status': 200,
#    'url': 'https://www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=1',
#    'domain': 'www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=1',
#    'header': {'cache-control': 'private, no-cache, no-store, max-age=0, must-revalidate',
#     'cf-cache-status': 'DYNAMIC',
#     'cf-ray': '897112ad7d973067-ICN',
#     'content-encoding': 'gzip',
#     'content-type': 'text/html; charset=utf-8',
#     'date': 'Fri, 21 Jun 2024 03:57:10 GMT',
#     'server': 'cloudflare',
#     'vary': 'Accept-Encoding',
#     'x-powered-by': 'Next.js'}},
#   'timestamp_page': 'Fri, 21 Jun 2024 03:57:10 GMT',
#   'timestamp_store': datetime.datetime(2024, 6, 21, 3, 57, 12, 758000),
#   'tag': '냉동'},
#  {'_id': ObjectId('6674fa22439eca10b0679166'),
#   'request': {'method': 'GET',
#    'url': 'https://www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=2',
#    'domain': 'www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=2',
#    'header': {'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#     'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
#     'referer': 'https://www.google.com',
#     'upgrade-insecure-requests': '1',
#     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
#     'sec-ch-ua': '"HeadlessChrome";v="125", "Chromium";v="125", "Not.A/Brand";v="24"',
#     'sec-ch-ua-mobile': '?0',
#     'sec-ch-ua-platform': '"Windows"'}},
#   'response': {'status': 200,
#    'url': 'https://www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=2',
#    'domain': 'www.kurly.com/search?sword=%EB%83%89%EB%8F%99&page=2',
#    'header': {'cache-control': 'private, no-cache, no-store, max-age=0, must-revalidate',
#     'cf-cache-status': 'DYNAMIC',
#     'cf-ray': '897112e94f1aaa5c-ICN',
#     'content-encoding': 'gzip',
#     'content-type': 'text/html; charset=utf-8',
#     'date': 'Fri, 21 Jun 2024 03:57:20 GMT',
#     'server': 'cloudflare',
#     'vary': 'Accept-Encoding',
#     'x-powered-by': 'Next.js'}},
#   'timestamp_page': 'Fri, 21 Jun 2024 03:57:20 GMT',
#   'timestamp_store': datetime.datetime(2024, 6, 21, 3, 57, 22, 287000),
#   'tag': '냉동'}]

# %%
def is_positive(x):
    return x > 0

@validate_inputs(is_positive)
def process_data(x):
    return x ** 2

process_data(3)
# Out:
# 9
